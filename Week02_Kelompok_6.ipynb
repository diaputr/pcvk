# %% [markdown]
# <a href="https://colab.research.google.com/github/diaputr/pcvk/blob/main/Week02_Kelompok_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# minta akses kedalam google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/Shareddrives/Yogi/TugasKul/SMT5/Pengolahan Citra dan Visi Komputer/singa.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB) # conversi BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/Shareddrives/Yogi/TugasKul/SMT5/Pengolahan Citra dan Visi Komputer/singa.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)

# tampilkan plot dengan ukurang canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100,100), radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300], [200,200],[400,300],[200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))  # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R, G, B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# #PERTANYAAN
#
# > Pemblokiran indentasi

# %% [markdown]
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# jawab:
#
# Matplotlib adalah library Python yang fokus pada visualisasi data seperti membuat plot grafik.Visualisasi dari matplotlib adalah sebuah gambar grafik yang terdapat satu sumbu atau lebih. Setiap sumbu memiliki sumbu horizontal (x) dan sumbu vertikal (y), dan data yang direpresentasikan menjadi warna dan glyphs seperti marker (contohnya bentuk lingkaran) atau lines (garis) atau poligon. Maka dari itu jika tanpa menggunakan metplotlib tidak muncul plot grafifk.
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
#
# jawab: Perbedaannya terletak pada hasil ukuran file image yang dihasilkan. Antara pembuatan black image tipe data int16 dengan int32, maka hasil ukuran file image yang dihasilkan lebih besar int32. Hal tersebut dapat mempengaruhi tingkat intensitas dari suatu image tersebut
#
# 3. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
#
# jawab :  import adalah fungsi Python untuk memanggil modul di luar fungsi dasar yang disediakan, cv2 adalah nama modul Python yang digunakan untuk memanggil fungsi-fungsi OpenCV, cv2_imshow perintah yang digunakan pada modul cv2 untuk menampilkan citra. Argumen yang diperlukan adalah nama citra yang dipanggil
#
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
#
# jawab: Saat diimpor, skimage menyimpan informasi untuk setiap piksel dalam array NumPy n-dimensi. Bentuk persegi panjang dari array sesuai dengan bentuk gambar, meskipun urutan koordinatnya terbalik.

# %% [markdown]
# #Tugas

# %% [markdown]
# Berdasarkan praktikum bagian 1 dan 2 kerjakan beberapa tugas berikut :

# %% [markdown]
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah?
#
# jawab:
